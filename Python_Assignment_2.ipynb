# %% [markdown]
# ## Question 1

# %%
for i in range(1,10):
    if i<6:
        for j in range(i):
            print('*',end='')
    else:
        for j in range(10-i):
            print('*',end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ## Question 2

# %%
word = input("Please enter a word: ")
word[::-1]
# Out:
# Please enter a word: ineuron
# 'norueni'
